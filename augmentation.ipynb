# %%
import numpy as np

def aug_rotate_90(image):
    print(image.shape)
    return np.transpose(image, (1, 0, 2))

def aug_horizontal_flip(image):
    return np.flip(image, axis=1)

def aug_vertical_flip(image):
    return np.flip(image, axis=0)

def aug_cut_out(image):
    width = np.random.randint(1, image.shape[0])//2
    height = np.random.randint(1, image.shape[1])//2
    start_width = np.random.randint(1, image.shape[0]-width)
    start_height = np.random.randint(1, image.shape[1]-height)
    image[start_width:start_width+width, start_height:start_height+height, :] = 0
    return image

def aug_add_gaussian_noise(image, mean=0, std=1.0):
    noisy_image = image + image * np.random.normal(mean, std, image.shape)
    noisy_image = np.clip(noisy_image, 0, 255)  
    return noisy_image.astype(np.uint8)

def aug_solarization(image):
    brightness_factor = 0.1 * (np.random.random(1).item() - 0.5)
    contrast_factor = 1.5 + 0.1 * (np.random.random(1).item() - 0.5)
    solarized_image = (image + brightness_factor) * contrast_factor
    solarized_image = np.clip(solarized_image, 0, 255)  
    return solarized_image.astype(np.uint8)

def aug_brightness(image):
    brightness_factor = (np.random.random(1).item() - 0.5)
    image = image + brightness_factor
    return (image + brightness_factor).astype(np.uint8)

def aug_contrast(image):
    contrast_factor = 1.0 + (np.random.random(1).item() - 0.5)
    return np.clip(image*contrast_factor, 0, 255).astype(np.uint8)

# %%
import glob, cv2, os


for image_path in glob.glob("data/train_images/*.jpg"):
    image = cv2.imread(image_path, 1)
    image = (image)
    aug = ""
    aug_image_path = ("data_augmented/train_images/"+image_path.rsplit("/")[-1]).replace(".jpg", aug+".jpg")
    aug_txt_path = image_path.replace("images", "annotations").replace(".jpg", ".txt")
    if not image is None: 
        if os.path.exists(aug_txt_path):
            with open(aug_txt_path, 'r') as file:
                content = file.readlines()
            print(image_path.replace("data","data_augmented").replace("images", "annotations").replace(".jpg", aug+".txt"))

            cv2.imwrite(aug_image_path, image)
            with open(aug_txt_path.replace("data","data_augmented").replace(".txt", aug+".txt"), 'w') as file:
                file.writelines(content)




#     # image_number
#     # save image number 2
#     # ...
#     # save same annotation with image_number_2...
# Out:
# data_augmented/train_annotations/p1324.txt
# data_augmented/train_annotations/p2018.txt
# data_augmented/train_annotations/p462.txt
# data_augmented/train_annotations/p1051.txt
# data_augmented/train_annotations/p499.txt
# data_augmented/train_annotations/p416.txt
# data_augmented/train_annotations/p1950.txt
# data_augmented/train_annotations/p1352.txt
# data_augmented/train_annotations/p422.txt
# data_augmented/train_annotations/p1240.txt
# data_augmented/train_annotations/p139.txt
# data_augmented/train_annotations/p412.txt
# data_augmented/train_annotations/p497.txt
# data_augmented/train_annotations/p2028.txt
# data_augmented/train_annotations/p1993.txt
# data_augmented/train_annotations/p1064.txt
# data_augmented/train_annotations/p1035.txt
# data_augmented/train_annotations/p1142.txt
# data_augmented/train_annotations/p138.txt
# data_augmented/train_annotations/p1147.txt
# data_augmented/train_annotations/p440.txt
# data_augmented/train_annotations/p1128.txt
# data_augmented/train_annotations/p1999.txt
# data_augmented/train_annotations/p123.txt
# data_augmented/train_annotations/p1287.txt
# data_augmented/train_annotations/p1439.txt
# data_augmented/train_annotations/p1235.txt
# data_augmented/train_annotations/p147.txt
# data_augmented/train_annotations/p1282.txt
# data_augmented/train_annotations/p1083.txt
# data_augmented/train_annotations/p1276.txt
# data_augmented/train_annotations/p1328.txt
# data_augmented/train_annotations/p1945.txt
# data_augmented/train_annotations/p478.txt
# data_augmented/train_annotations/p1054.txt
# data_augmented/train_annotations/p1242.txt
# data_augmented/train_annotations/p1986.txt
# data_augmented/train_annotations/p1236.txt
# data_augmented/train_annotations/p442.txt
# data_augmented/train_annotations/p1272.txt
# data_augmented/train_annotations/p1956.txt
# data_augmented/train_annotations/p1197.txt
# data_augmented/train_annotations/p475.txt
# data_augmented/train_annotations/p1138.txt
# data_augmented/train_annotations/p1251.txt
# data_augmented/train_annotations/p1271.txt
# data_augmented/train_annotations/p149.txt
# data_augmented/train_annotations/p1049.txt
# data_augmented/train_annotations/p1169.txt
# data_augmented/train_annotations/p1202.txt
# data_augmented/train_annotations/p141.txt
# data_augmented/train_annotations/p1184.txt
# data_augmented/train_annotations/p1269.txt
# data_augmented/train_annotations/p1923.txt
# data_augmented/train_annotations/p420.txt
# data_augmented/train_annotations/p1095.txt
# data_augmented/train_annotations/p2017.txt
# data_augmented/train_annotations/p451.txt
# data_augmented/train_annotations/p425.txt
# data_augmented/train_annotations/p1174.txt
# data_augmented/train_annotations/p432.txt
# data_augmented/train_annotations/p1232.txt
# data_augmented/train_annotations/p469.txt
# data_augmented/train_annotations/p1980.txt
# data_augmented/train_annotations/p1052.txt
# data_augmented/train_annotations/p1224.txt
# data_augmented/train_annotations/p449.txt
# data_augmented/train_annotations/p1939.txt
# data_augmented/train_annotations/p417.txt
# data_augmented/train_annotations/p1425.txt
# data_augmented/train_annotations/p1304.txt
# data_augmented/train_annotations/p1337.txt
# data_augmented/train_annotations/p1978.txt
# data_augmented/train_annotations/p1997.txt
# data_augmented/train_annotations/p1925.txt
# data_augmented/train_annotations/p1960.txt
# data_augmented/train_annotations/p468.txt
# data_augmented/train_annotations/p2023.txt
# data_augmented/train_annotations/p1443.txt
# data_augmented/train_annotations/p1213.txt
# data_augmented/train_annotations/p1969.txt
# data_augmented/train_annotations/p1043.txt
# data_augmented/train_annotations/p1120.txt
# data_augmented/train_annotations/p1113.txt
# data_augmented/train_annotations/p1955.txt
# data_augmented/train_annotations/p1418.txt
# data_augmented/train_annotations/p1077.txt
# data_augmented/train_annotations/p1204.txt
# data_augmented/train_annotations/p1100.txt
# data_augmented/train_annotations/p477.txt
# data_augmented/train_annotations/p405.txt
# data_augmented/train_annotations/p124.txt
# data_augmented/train_annotations/p1990.txt
# data_augmented/train_annotations/p1229.txt
# data_augmented/train_annotations/p1995.txt
# data_augmented/train_annotations/p1445.txt
# data_augmented/train_annotations/p2007.txt
# data_augmented/train_annotations/p1940.txt
# data_augmented/train_annotations/p427.txt
# data_augmented/train_annotations/p2003.txt
# data_augmented/train_annotations/p415.txt
# data_augmented/train_annotations/p102.txt
# data_augmented/train_annotations/p1988.txt
# data_augmented/train_annotations/p1048.txt
# data_augmented/train_annotations/p1063.txt
# data_augmented/train_annotations/p1433.txt
# data_augmented/train_annotations/p1309.txt
# data_augmented/train_annotations/p1246.txt
# data_augmented/train_annotations/p1130.txt
# data_augmented/train_annotations/p1238.txt
# data_augmented/train_annotations/p1155.txt
# data_augmented/train_annotations/p1957.txt
# data_augmented/train_annotations/p1227.txt
# data_augmented/train_annotations/p2022.txt
# data_augmented/train_annotations/p1078.txt
# data_augmented/train_annotations/p2004.txt
# data_augmented/train_annotations/p1116.txt
# data_augmented/train_annotations/p441.txt
# data_augmented/train_annotations/p117.txt
# data_augmented/train_annotations/p1431.txt
# data_augmented/train_annotations/p1976.txt
# data_augmented/train_annotations/p1323.txt
# data_augmented/train_annotations/p1968.txt
# data_augmented/train_annotations/p1143.txt
# data_augmented/train_annotations/p453.txt
# data_augmented/train_annotations/p2008.txt
# data_augmented/train_annotations/p2013.txt
# data_augmented/train_annotations/p423.txt
# data_augmented/train_annotations/p1314.txt
# data_augmented/train_annotations/p1944.txt
# data_augmented/train_annotations/p2002.txt
# data_augmented/train_annotations/p110.txt
# data_augmented/train_annotations/p437.txt
# data_augmented/train_annotations/p1346.txt
# data_augmented/train_annotations/p1930.txt
# data_augmented/train_annotations/p1977.txt
# data_augmented/train_annotations/p1122.txt
# data_augmented/train_annotations/p128.txt
# data_augmented/train_annotations/p148.txt
# data_augmented/train_annotations/p1192.txt
# data_augmented/train_annotations/p426.txt
# data_augmented/train_annotations/p1119.txt
# data_augmented/train_annotations/p1299.txt
# data_augmented/train_annotations/p1316.txt
# data_augmented/train_annotations/p132.txt
# data_augmented/train_annotations/p1212.txt
# data_augmented/train_annotations/p1302.txt
# data_augmented/train_annotations/p1056.txt
# data_augmented/train_annotations/p1267.txt
# data_augmented/train_annotations/p136.txt
# data_augmented/train_annotations/p1117.txt
# data_augmented/train_annotations/p142.txt
# data_augmented/train_annotations/p1092.txt
# data_augmented/train_annotations/p2006.txt
# data_augmented/train_annotations/p1166.txt
# data_augmented/train_annotations/p1248.txt
# data_augmented/train_annotations/p1341.txt
# data_augmented/train_annotations/p2027.txt
# data_augmented/train_annotations/p431.txt
# data_augmented/train_annotations/p1226.txt
# data_augmented/train_annotations/p1406.txt
# data_augmented/train_annotations/p1291.txt
# data_augmented/train_annotations/p1194.txt
# data_augmented/train_annotations/p1266.txt
# data_augmented/train_annotations/p1414.txt
# data_augmented/train_annotations/p1165.txt
# data_augmented/train_annotations/p463.txt
# data_augmented/train_annotations/p121.txt
# data_augmented/train_annotations/p454.txt
# data_augmented/train_annotations/p1984.txt
# data_augmented/train_annotations/p1038.txt
# data_augmented/train_annotations/p1243.txt
# data_augmented/train_annotations/p1985.txt
# data_augmented/train_annotations/p1931.txt
# data_augmented/train_annotations/p2029.txt
# data_augmented/train_annotations/p1413.txt
# data_augmented/train_annotations/p1207.txt
# data_augmented/train_annotations/p1139.txt
# data_augmented/train_annotations/p1335.txt
# data_augmented/train_annotations/p411.txt
# data_augmented/train_annotations/p1936.txt
# data_augmented/train_annotations/p1929.txt
# data_augmented/train_annotations/p413.txt
# data_augmented/train_annotations/p498.txt
# data_augmented/train_annotations/p1357.txt
# data_augmented/train_annotations/p1971.txt
# data_augmented/train_annotations/p1943.txt
# data_augmented/train_annotations/p1176.txt
# data_augmented/train_annotations/p1983.txt
# data_augmented/train_annotations/p1959.txt
# data_augmented/train_annotations/p1331.txt
# data_augmented/train_annotations/p407.txt
# data_augmented/train_annotations/p1321.txt
# data_augmented/train_annotations/p1141.txt
# data_augmented/train_annotations/p1264.txt
# data_augmented/train_annotations/p1200.txt
# data_augmented/train_annotations/p1305.txt
# data_augmented/train_annotations/p125.txt
# data_augmented/train_annotations/p1982.txt
# data_augmented/train_annotations/p1121.txt
# data_augmented/train_annotations/p1089.txt
# data_augmented/train_annotations/p1303.txt
# data_augmented/train_annotations/p1412.txt
# data_augmented/train_annotations/p1182.txt
# data_augmented/train_annotations/p1118.txt
# data_augmented/train_annotations/p1972.txt
# data_augmented/train_annotations/p1297.txt
# data_augmented/train_annotations/p1055.txt
# data_augmented/train_annotations/p1354.txt
# data_augmented/train_annotations/p1274.txt
# data_augmented/train_annotations/p1218.txt
# data_augmented/train_annotations/p1953.txt
# data_augmented/train_annotations/p418.txt
# data_augmented/train_annotations/p1135.txt
# data_augmented/train_annotations/p1952.txt
# data_augmented/train_annotations/p444.txt
# data_augmented/train_annotations/p1315.txt
# data_augmented/train_annotations/p430.txt
# data_augmented/train_annotations/p1234.txt
# data_augmented/train_annotations/p1245.txt
# data_augmented/train_annotations/p122.txt
# data_augmented/train_annotations/p127.txt
# data_augmented/train_annotations/p1167.txt
# data_augmented/train_annotations/p1178.txt
# data_augmented/train_annotations/p1946.txt
# data_augmented/train_annotations/p1961.txt
# data_augmented/train_annotations/p1428.txt
# data_augmented/train_annotations/p1080.txt
# data_augmented/train_annotations/p424.txt
# data_augmented/train_annotations/p1196.txt
# data_augmented/train_annotations/p1336.txt
# data_augmented/train_annotations/p447.txt
# data_augmented/train_annotations/p1326.txt
# data_augmented/train_annotations/p1189.txt
# data_augmented/train_annotations/p1942.txt
# data_augmented/train_annotations/p1065.txt
# data_augmented/train_annotations/p1096.txt
# data_augmented/train_annotations/p1935.txt
# data_augmented/train_annotations/p443.txt
# data_augmented/train_annotations/p1168.txt
# data_augmented/train_annotations/p429.txt
# data_augmented/train_annotations/p1173.txt
# data_augmented/train_annotations/p1286.txt
# data_augmented/train_annotations/p1979.txt
# data_augmented/train_annotations/p461.txt
# data_augmented/train_annotations/p146.txt
# data_augmented/train_annotations/p1033.txt
# data_augmented/train_annotations/p1099.txt
# data_augmented/train_annotations/p1107.txt
# data_augmented/train_annotations/p1199.txt
# data_augmented/train_annotations/p1133.txt
# data_augmented/train_annotations/p1221.txt
# data_augmented/train_annotations/p1998.txt
# data_augmented/train_annotations/p1214.txt
# data_augmented/train_annotations/p1106.txt
# data_augmented/train_annotations/p1355.txt
# data_augmented/train_annotations/p1170.txt
# data_augmented/train_annotations/p500.txt
# data_augmented/train_annotations/p1061.txt
# data_augmented/train_annotations/p1125.txt
# data_augmented/train_annotations/p1268.txt
# data_augmented/train_annotations/p1208.txt
# data_augmented/train_annotations/p1157.txt
# data_augmented/train_annotations/p1090.txt
# data_augmented/train_annotations/p1966.txt
# data_augmented/train_annotations/p1260.txt
# data_augmented/train_annotations/p1970.txt
# data_augmented/train_annotations/p1934.txt
# data_augmented/train_annotations/p1926.txt
# data_augmented/train_annotations/p1283.txt
# data_augmented/train_annotations/p134.txt
# data_augmented/train_annotations/p126.txt
# data_augmented/train_annotations/p1102.txt
# data_augmented/train_annotations/p140.txt
# data_augmented/train_annotations/p1108.txt
# data_augmented/train_annotations/p116.txt
# data_augmented/train_annotations/p2015.txt
# data_augmented/train_annotations/p1292.txt
# data_augmented/train_annotations/p419.txt
# data_augmented/train_annotations/p1258.txt
# data_augmented/train_annotations/p1334.txt
# data_augmented/train_annotations/p1230.txt
# data_augmented/train_annotations/p109.txt
# data_augmented/train_annotations/p1358.txt
# data_augmented/train_annotations/p1284.txt
# data_augmented/train_annotations/p1069.txt
# data_augmented/train_annotations/p1306.txt
# data_augmented/train_annotations/p428.txt
# data_augmented/train_annotations/p1114.txt
# data_augmented/train_annotations/p1994.txt
# data_augmented/train_annotations/p410.txt
# data_augmented/train_annotations/p1424.txt
# data_augmented/train_annotations/p1345.txt
# data_augmented/train_annotations/p1318.txt
# data_augmented/train_annotations/p1074.txt
# data_augmented/train_annotations/p1294.txt
# data_augmented/train_annotations/p476.txt
# data_augmented/train_annotations/p435.txt
# data_augmented/train_annotations/p1263.txt
# data_augmented/train_annotations/p1075.txt
# data_augmented/train_annotations/p1332.txt
# data_augmented/train_annotations/p2026.txt
# data_augmented/train_annotations/p1349.txt
# data_augmented/train_annotations/p1320.txt
# data_augmented/train_annotations/p135.txt
# data_augmented/train_annotations/p1047.txt
# data_augmented/train_annotations/p1187.txt
# data_augmented/train_annotations/p439.txt
# data_augmented/train_annotations/p1172.txt
# data_augmented/train_annotations/p433.txt
# data_augmented/train_annotations/p1310.txt
# data_augmented/train_annotations/p1159.txt
# data_augmented/train_annotations/p1420.txt
# data_augmented/train_annotations/p1036.txt
# data_augmented/train_annotations/p1281.txt
# data_augmented/train_annotations/p2025.txt
# data_augmented/train_annotations/p1228.txt
# data_augmented/train_annotations/p445.txt
# data_augmented/train_annotations/p1131.txt
# data_augmented/train_annotations/p1087.txt
# data_augmented/train_annotations/p1259.txt
# data_augmented/train_annotations/p111.txt
# data_augmented/train_annotations/p1193.txt
# data_augmented/train_annotations/p1231.txt
# data_augmented/train_annotations/p408.txt
# data_augmented/train_annotations/p1185.txt
# data_augmented/train_annotations/p1991.txt
# data_augmented/train_annotations/p118.txt
# data_augmented/train_annotations/p1071.txt
# data_augmented/train_annotations/p446.txt
# data_augmented/train_annotations/p465.txt
# data_augmented/train_annotations/p1140.txt
# data_augmented/train_annotations/p1410.txt
# data_augmented/train_annotations/p2011.txt
# data_augmented/train_annotations/p1356.txt
# data_augmented/train_annotations/p1216.txt
# data_augmented/train_annotations/p452.txt
# data_augmented/train_annotations/p1928.txt
# data_augmented/train_annotations/p1073.txt
# data_augmented/train_annotations/p1408.txt
# data_augmented/train_annotations/p1059.txt
# data_augmented/train_annotations/p1070.txt
# data_augmented/train_annotations/p1247.txt
# data_augmented/train_annotations/p1233.txt
# data_augmented/train_annotations/p1154.txt
# data_augmented/train_annotations/p1072.txt
# data_augmented/train_annotations/p1253.txt
# data_augmented/train_annotations/p460.txt
# data_augmented/train_annotations/p1104.txt
# data_augmented/train_annotations/p1325.txt
# data_augmented/train_annotations/p1081.txt
# data_augmented/train_annotations/p2024.txt
# data_augmented/train_annotations/p1219.txt
# data_augmented/train_annotations/p1312.txt
# data_augmented/train_annotations/p409.txt
# data_augmented/train_annotations/p1288.txt
# data_augmented/train_annotations/p2001.txt
# data_augmented/train_annotations/p1416.txt
# data_augmented/train_annotations/p1109.txt
# data_augmented/train_annotations/p1949.txt
# data_augmented/train_annotations/p1129.txt
# data_augmented/train_annotations/p2020.txt
# data_augmented/train_annotations/p115.txt
# data_augmented/train_annotations/p1347.txt
# data_augmented/train_annotations/p1103.txt
# data_augmented/train_annotations/p1989.txt
# data_augmented/train_annotations/p1034.txt
# data_augmented/train_annotations/p1295.txt
# data_augmented/train_annotations/p1449.txt
# data_augmented/train_annotations/p2012.txt
# data_augmented/train_annotations/p2016.txt
# data_augmented/train_annotations/p1298.txt
# data_augmented/train_annotations/p1350.txt
# data_augmented/train_annotations/p1308.txt
# data_augmented/train_annotations/p474.txt
# data_augmented/train_annotations/p1058.txt
# data_augmented/train_annotations/p1060.txt
# data_augmented/train_annotations/p1105.txt
# data_augmented/train_annotations/p1164.txt
# data_augmented/train_annotations/p1190.txt
# data_augmented/train_annotations/p1149.txt
# data_augmented/train_annotations/p1112.txt
# data_augmented/train_annotations/p1210.txt
# data_augmented/train_annotations/p471.txt
# data_augmented/train_annotations/p1342.txt
# data_augmented/train_annotations/p2000.txt
# data_augmented/train_annotations/p414.txt
# data_augmented/train_annotations/p1343.txt
# data_augmented/train_annotations/p1171.txt
# data_augmented/train_annotations/p129.txt
# data_augmented/train_annotations/p421.txt
# data_augmented/train_annotations/p1987.txt
# data_augmented/train_annotations/p1088.txt
# data_augmented/train_annotations/p1039.txt
# data_augmented/train_annotations/p1932.txt
# data_augmented/train_annotations/p1195.txt
# data_augmented/train_annotations/p1180.txt
# data_augmented/train_annotations/p2009.txt
# data_augmented/train_annotations/p1186.txt
# data_augmented/train_annotations/p1082.txt
# data_augmented/train_annotations/p1965.txt
# data_augmented/train_annotations/p1123.txt
# data_augmented/train_annotations/p467.txt
# data_augmented/train_annotations/p1265.txt
# data_augmented/train_annotations/p456.txt
# data_augmented/train_annotations/p1941.txt
# data_augmented/train_annotations/p1111.txt
# data_augmented/train_annotations/p1144.txt
# data_augmented/train_annotations/p1203.txt
# data_augmented/train_annotations/p1084.txt
# data_augmented/train_annotations/p1974.txt
# data_augmented/train_annotations/p1148.txt
# data_augmented/train_annotations/p1127.txt
# data_augmented/train_annotations/p448.txt
# data_augmented/train_annotations/p1254.txt
# data_augmented/train_annotations/p101.txt
# data_augmented/train_annotations/p1938.txt
# data_augmented/train_annotations/p1041.txt
# data_augmented/train_annotations/p1442.txt
# data_augmented/train_annotations/p1277.txt
# data_augmented/train_annotations/p1225.txt
# data_augmented/train_annotations/p1975.txt
# data_augmented/train_annotations/p1201.txt
# data_augmented/train_annotations/p2021.txt
# data_augmented/train_annotations/p1183.txt
# data_augmented/train_annotations/p1110.txt
# data_augmented/train_annotations/p1429.txt
# data_augmented/train_annotations/p1951.txt
# data_augmented/train_annotations/p1158.txt
# data_augmented/train_annotations/p107.txt
# data_augmented/train_annotations/p1079.txt
# data_augmented/train_annotations/p1097.txt
# data_augmented/train_annotations/p1153.txt
# data_augmented/train_annotations/p1440.txt
# data_augmented/train_annotations/p1156.txt
# data_augmented/train_annotations/p106.txt
# data_augmented/train_annotations/p1963.txt
# data_augmented/train_annotations/p150.txt
# data_augmented/train_annotations/p1091.txt
# data_augmented/train_annotations/p1973.txt
# data_augmented/train_annotations/p466.txt
# data_augmented/train_annotations/p1333.txt
# data_augmented/train_annotations/p1076.txt
# data_augmented/train_annotations/p1275.txt
# data_augmented/train_annotations/p1062.txt
# data_augmented/train_annotations/p1037.txt
# data_augmented/train_annotations/p1098.txt
# data_augmented/train_annotations/p1344.txt
# data_augmented/train_annotations/p1407.txt
# data_augmented/train_annotations/p1032.txt
# data_augmented/train_annotations/p2019.txt
# data_augmented/train_annotations/p120.txt
# data_augmented/train_annotations/p1257.txt
# data_augmented/train_annotations/p2014.txt
# data_augmented/train_annotations/p1160.txt
# data_augmented/train_annotations/p112.txt
# data_augmented/train_annotations/p1101.txt
# data_augmented/train_annotations/p1313.txt
# data_augmented/train_annotations/p1992.txt
# data_augmented/train_annotations/p1285.txt
# data_augmented/train_annotations/p404.txt
# data_augmented/train_annotations/p472.txt
# data_augmented/train_annotations/p113.txt
# data_augmented/train_annotations/p438.txt
# data_augmented/train_annotations/p1179.txt
# data_augmented/train_annotations/p1981.txt
# data_augmented/train_annotations/p1417.txt
# data_augmented/train_annotations/p1962.txt
# data_augmented/train_annotations/p2005.txt
# data_augmented/train_annotations/p119.txt
# data_augmented/train_annotations/p1427.txt
# data_augmented/train_annotations/p1042.txt
# data_augmented/train_annotations/p1177.txt
# data_augmented/train_annotations/p133.txt
# data_augmented/train_annotations/p1293.txt
# data_augmented/train_annotations/p1948.txt
# data_augmented/train_annotations/p1256.txt
# data_augmented/train_annotations/p1137.txt
# data_augmented/train_annotations/p1126.txt
# data_augmented/train_annotations/p1217.txt
# data_augmented/train_annotations/p145.txt
# data_augmented/train_annotations/p455.txt
